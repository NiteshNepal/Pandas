# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Reading Different File Format

# %%
df=pd.read_csv("Titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
#It will show top 5 record.
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
#It will show last 5 record
df.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
#we can save the above df into another csv file.
df.to_csv("Hello World.csv")

# %%
df2=pd.read_csv("Hello World.csv")
df2.head()
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0          892         0       3
# 1           1          893         1       3
# 2           2          894         0       2
# 3           3          895         0       3
# 4           4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
#we can save only specific column of the data even without index also.
df.to_csv("Hello World 2.csv",index=False,columns=["PassengerId","Survived"])

# %%
df4=pd.read_csv("Hello World 2.csv")
df4.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
#we can give our own name as header.
df2=pd.read_csv("Hello World.csv",header=None,names=["a","b","c","d","e","f","g","h","i","j","k","l","m"])
df2.head()
# Out:
#      a            b         c       d                                 e  \
# 0  NaN  PassengerId  Survived  Pclass                              Name
# 1  0.0          892         0       3                  Kelly, Mr. James
# 2  1.0          893         1       3  Wilkes, Mrs. James (Ellen Needs)
# 3  2.0          894         0       2         Myles, Mr. Thomas Francis
# 4  3.0          895         0       3                  Wirz, Mr. Albert
#
#         f     g      h      i       j       k      l         m
# 0     Sex   Age  SibSp  Parch  Ticket    Fare  Cabin  Embarked
# 1    male  34.5      0      0  330911  7.8292    NaN         Q
# 2  female  47.0      1      0  363272     7.0    NaN         S
# 3    male  62.0      0      0  240276  9.6875    NaN         Q
# 4    male  27.0      0      0  315154  8.6625    NaN         S

# %%
#we can give our own name as header and skip some rows.
df2=pd.read_csv("Hello World.csv",header=None,names=["a","b","c","d","e","f","g","h","i","j","k","l","m"],skiprows=[0,1,2])
df2.head()
# Out:
#    a    b  c  d                                             e       f     g  \
# 0  2  894  0  2                     Myles, Mr. Thomas Francis    male  62.0
# 1  3  895  0  3                              Wirz, Mr. Albert    male  27.0
# 2  4  896  1  3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# 3  5  897  0  3                    Svensson, Mr. Johan Cervin    male  14.0
# 4  6  898  1  3                          Connolly, Miss. Kate  female  30.0
#
#    h  i        j        k    l  m
# 0  0  0   240276   9.6875  NaN  Q
# 1  0  0   315154   8.6625  NaN  S
# 2  1  1  3101298  12.2875  NaN  S
# 3  0  0     7538   9.2250  NaN  S
# 4  0  0   330972   7.6292  NaN  Q

# %%
#we can make any data null by the below operation.
#for example: we converted the PassengerId's 892,893 value into NAN.
df3=pd.read_csv("Hello World.csv",na_values=[892,893])
df3.head()
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0          NaN         0       3
# 1           1          NaN         1       3
# 2           2        894.0         0       2
# 3           3        895.0         0       3
# 4           4        896.0         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#we can find so much of insights of data by the help of describe method.
#By the help of this, we can find the numerical values,either there is missing value or not by just looking at count.
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#we can access any specific columns.
df[["PassengerId","Embarked","Sex"]]
# Out:
#      PassengerId Embarked     Sex
# 0            892        Q    male
# 1            893        S  female
# 2            894        Q    male
# 3            895        S    male
# 4            896        S  female
# ..           ...      ...     ...
# 413         1305        S    male
# 414         1306        C  female
# 415         1307        S    male
# 416         1308        S    male
# 417         1309        C    male
#
# [418 rows x 3 columns]

# %%
#we can read html,excel etc using pandas.
df5 = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2023.html")

# %%
type(df5)
# Out:
# list

# %%
#we can find total number of tabular data present in that html file.
len(df5)
# Out:
# 13

# %%
#It will extract the 5th index table data.
df5[5].head()
# Out:
#     Rk                  Team   G     MP    FG   FGA    FG%    3P   3PA    3P%  \
# 0  1.0   Cleveland Cavaliers  61  242.9  38.9  83.5  0.465  11.3  30.8  0.366
# 1  2.0            Miami Heat  59  241.7  39.5  82.7  0.477  13.1  35.7  0.367
# 2  3.0    Philadelphia 76ers  57  242.2  40.3  85.4  0.472  11.2  32.6  0.344
# 3  4.0  Los Angeles Clippers  61  241.2  41.0  87.1  0.470  12.2  33.6  0.364
# 4  5.0          Phoenix Suns  60  241.7  40.1  85.7  0.467  11.4  31.7  0.359
#
#    ...    FT%   ORB   DRB   TRB   AST  STL  BLK   TOV    PF    PTS
# 0  ...  0.775   9.3  30.9  40.2  22.8  7.3  4.2  15.1  21.0  106.1
# 1  ...  0.771   8.6  33.6  42.2  25.2  6.8  3.9  16.3  19.9  108.3
# 2  ...  0.785   9.8  32.2  42.0  23.8  6.7  4.8  15.0  19.8  110.5
# 3  ...  0.759   9.9  33.1  43.0  24.5  7.6  4.2  13.0  19.5  111.1
# 4  ...  0.791  10.4  32.6  42.9  23.6  7.5  4.0  15.0  20.3  111.3
#
# [5 rows x 25 columns]

# %%
import json

# %%
s1 ="""{
"Name": "Nitesh",
"Address":"Kathmandu",
"Phone_no": 7766554433
}"""

# %%
s=json.loads(s1)

# %%
s
# Out:
# {'Name': 'Nitesh', 'Address': 'Kathmandu', 'Phone_no': 7766554433}

# %%
import requests

# %%
res=requests.get("https://api.github.com/repos/pandas-dev/pandas/issues")

# %%
res
# Out:
# <Response [200]>

# %%
#converting the info in the url into json file.
df6=res.json()

# %%
#we can check if the json file is working or not using jsonviewer.
df6
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51485',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51485/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51485/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51485/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/51485',
#   'id': 1590550162,
#   'node_id': 'PR_kwDOAA0YD85KR1aO',
#   'number': 51485,
#   'title': 'BUG: Fix NameError in tab complete warning test',
#   'user': {'login': 'smij720',
#    'id': 122238526,
#    'node_id': 'U_kgDOB0k2Pg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/122238526?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/smij720',
#    'html_url': 'https://github.com/smij720',
#    'followers_url': 'https://api.github.com/users/smij720/followers',
# ...

# %%
df6[0]["title"]
# Out:
# 'BUG: Fix NameError in tab complete warning test'

# %%
for i in range(len(df6)):
    print(df6[i]['title'])
# Out:
# BUG: Fix NameError in tab complete warning test
# BUG: Fix error message for unknown methodtype
# REF: de-duplicate precision_from_unit
# REF: de-duplicate NDFrame.take, remove Manager.take keyword
# DEP: Enforce deprecation of squeeze in read_excel
# TYP: Use Self instead of class-bound TypeVar in pyi files (remove Y019)
# REF: stricter typing in Manager.take
# WIP/DEPR: silently ignoring unrecognized timezones
# BUG: inferring incorrect datetime format
# validate_percentile error message
# PERF: using _reduce_axis1 to improve perf in df.sum,min, max with axis=1
# TYP: misc typing from pandas-stubs in io and plotting
# PERF: DataFrame.clip / Series.clip
# ENH: Extending EAs
# DEPS: Partial Matplotlib 3.7 support
# DOC: Remove 1.0.0 versionadded/versionchanged
# Render PDEPs using sphinx
# PDEP 8: Inplace methods in pandas
# CoW: Ignore copy=True when copy_on_write is enabled
# PDEP-7: Consistent copy/view semantics in pandas with Copy-on-Write
# ...

# %%
pd.DataFrame(df6).head()
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
# 2  https://api.github.com/repos/pandas-dev/pandas
# 3  https://api.github.com/repos/pandas-dev/pandas
# 4  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
# ...

# %%
df6[0]['user']
# Out:
# {'login': 'smij720',
#  'id': 122238526,
#  'node_id': 'U_kgDOB0k2Pg',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/122238526?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/smij720',
#  'html_url': 'https://github.com/smij720',
#  'followers_url': 'https://api.github.com/users/smij720/followers',
#  'following_url': 'https://api.github.com/users/smij720/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/smij720/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/smij720/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/smij720/subscriptions',
#  'organizations_url': 'https://api.github.com/users/smij720/orgs',
#  'repos_url': 'https://api.github.com/users/smij720/repos',
#  'events_url': 'https://api.github.com/users/smij720/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/smij720/received_events',
#  'type': 'User',
#  'site_admin': False}

# %%
df7=pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
dff=pd.DataFrame.from_records(df7["user"])
dff.head()
# Out:
#           login         id               node_id  \
# 0       smij720  122238526          U_kgDOB0k2Pg
# 1       yeesian    1231079  MDQ6VXNlcjEyMzEwNzk=
# 2  jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 3  jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 4         phofl   61934744  MDQ6VXNlcjYxOTM0NzQ0
#
#                                           avatar_url gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/122238...
# 1  https://avatars.githubusercontent.com/u/123107...
# 2  https://avatars.githubusercontent.com/u/807896...
# 3  https://avatars.githubusercontent.com/u/807896...
# 4  https://avatars.githubusercontent.com/u/619347...
#
#                                          url                         html_url  \
# 0       https://api.github.com/users/smij720       https://github.com/smij720
# 1       https://api.github.com/users/yeesian       https://github.com/yeesian
# 2  https://api.github.com/users/jbrockmendel  https://github.com/jbrockmendel
# ...

# %%
df=pd.read_csv("Titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
#A PICKLE file is a byte stream created by pickle, a Python module that can serialize(not readable form) objects to files on a disk.
#It is a kind of binary data format inside pandas.
#pickle simply convert the actual data into byte code and serialize the data.
"""Serialization---->converting object to bytecode
Deserialization---->bytecode to object"""
df.to_pickle("Hello World 3")

# %%
pwd()
# Out:
# 'C:\\Users\\asus'

# %% [markdown]
# ### Panda Basics

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.dtypes == "O"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df1=df[df.dtypes[df.dtypes == "O"].index]
df1
# Out:
#                                              Name     Sex              Ticket  \
# 0                                Kelly, Mr. James    male              330911
# 1                Wilkes, Mrs. James (Ellen Needs)  female              363272
# 2                       Myles, Mr. Thomas Francis    male              240276
# 3                                Wirz, Mr. Albert    male              315154
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female             3101298
# ..                                            ...     ...                 ...
# 413                            Spector, Mr. Woolf    male           A.5. 3236
# 414                  Oliva y Ocana, Dona. Fermina  female            PC 17758
# 415                  Saether, Mr. Simon Sivertsen    male  SOTON/O.Q. 3101262
# 416                           Ware, Mr. Frederick    male              359309
# 417                      Peter, Master. Michael J    male                2668
#
#     Cabin Embarked
# ...

# %%
#it is possible to get the description of categorical feature as well.
#but by default pandas will not give the description of categorical feature.
df1.describe()
# Out:
#                     Name   Sex    Ticket            Cabin Embarked
# count                418   418       418               91      418
# unique               418     2       363               76        3
# top     Kelly, Mr. James  male  PC 17608  B57 B59 B63 B66        S
# freq                   1   266         5                3      270

# %%
df2=df[df.dtypes[df.dtypes == "float64"].index]
df2
# Out:
#       Age      Fare
# 0    34.5    7.8292
# 1    47.0    7.0000
# 2    62.0    9.6875
# 3    27.0    8.6625
# 4    22.0   12.2875
# ..    ...       ...
# 413   NaN    8.0500
# 414  39.0  108.9000
# 415  38.5    7.2500
# 416   NaN    8.0500
# 417   NaN   22.3583
#
# [418 rows x 2 columns]

# %%
df[["Age","Fare"]]
# Out:
#       Age      Fare
# 0    34.5    7.8292
# 1    47.0    7.0000
# 2    62.0    9.6875
# 3    27.0    8.6625
# 4    22.0   12.2875
# ..    ...       ...
# 413   NaN    8.0500
# 414  39.0  108.9000
# 415  38.5    7.2500
# 416   NaN    8.0500
# 417   NaN   22.3583
#
# [418 rows x 2 columns]

# %%
#series
df["Name"]
# Out:
# 0                                  Kelly, Mr. James
# 1                  Wilkes, Mrs. James (Ellen Needs)
# 2                         Myles, Mr. Thomas Francis
# 3                                  Wirz, Mr. Albert
# 4      Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#                            ...
# 413                              Spector, Mr. Woolf
# 414                    Oliva y Ocana, Dona. Fermina
# 415                    Saether, Mr. Simon Sivertsen
# 416                             Ware, Mr. Frederick
# 417                        Peter, Master. Michael J
# Name: Name, Length: 418, dtype: object

# %%
#DataFrame
df[["Name"]]
# Out:
#                                              Name
# 0                                Kelly, Mr. James
# 1                Wilkes, Mrs. James (Ellen Needs)
# 2                       Myles, Mr. Thomas Francis
# 3                                Wirz, Mr. Albert
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..                                            ...
# 413                            Spector, Mr. Woolf
# 414                  Oliva y Ocana, Dona. Fermina
# 415                  Saether, Mr. Simon Sivertsen
# 416                           Ware, Mr. Frederick
# 417                      Peter, Master. Michael J
#
# [418 rows x 1 columns]

# %%
type(df["PassengerId"])
# Out:
# pandas.core.series.Series

# %%
type(df[["PassengerId"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df[["Age"]][1:10:2]
# Out:
#     Age
# 1  47.0
# 3  27.0
# 5  14.0
# 7  26.0
# 9  21.0

# %%
df[["Ticket"]][1:10]
# Out:
#       Ticket
# 1     363272
# 2     240276
# 3     315154
# 4    3101298
# 5       7538
# 6     330972
# 7     248738
# 8       2657
# 9  A/4 48871

# %%
[df.columns]
# Out:
# [Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#         'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#        dtype='object')]

# %%
#we can insert our own column in the dataframe.
df["Ocean"]="North Atlantic"

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked           Ocean
# 0   330911   7.8292   NaN        Q  North Atlantic
# 1   363272   7.0000   NaN        S  North Atlantic
# 2   240276   9.6875   NaN        Q  North Atlantic
# 3   315154   8.6625   NaN        S  North Atlantic
# ...

# %%
df["Class"]=df["Pclass"]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked           Ocean  Class
# 0   330911   7.8292   NaN        Q  North Atlantic      3
# 1   363272   7.0000   NaN        S  North Atlantic      3
# 2   240276   9.6875   NaN        Q  North Atlantic      2
# 3   315154   8.6625   NaN        S  North Atlantic      3
# ...

# %%
pd.Categorical(df["Sex"])
# Out:
# ['male', 'female', 'male', 'male', 'female', ..., 'male', 'female', 'male', 'male', 'male']
# Length: 418
# Categories (2, object): ['female', 'male']

# %%
pd.Categorical(df["Survived"])
# Out:
# [0, 1, 0, 0, 1, ..., 0, 1, 0, 0, 0]
# Length: 418
# Categories (2, int64): [0, 1]

# %%
#unique value in the feature.
df["Class"].unique()
# Out:
# array([3, 2, 1], dtype=int64)

# %%
#if there is any null value in the dataframe.
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# Ocean            0
# Class            0
# dtype: int64

# %%
age_null= df["Age"][df["Age"].isnull() == True]

# %%
age_null.index
# Out:
# Int64Index([ 10,  22,  29,  33,  36,  39,  41,  47,  54,  58,  65,  76,  83,
#              84,  85,  88,  91,  93, 102, 107, 108, 111, 116, 121, 124, 127,
#             132, 133, 146, 148, 151, 160, 163, 168, 170, 173, 183, 188, 191,
#             199, 200, 205, 211, 216, 219, 225, 227, 233, 243, 244, 249, 255,
#             256, 265, 266, 267, 268, 271, 273, 274, 282, 286, 288, 289, 290,
#             292, 297, 301, 304, 312, 332, 339, 342, 344, 357, 358, 365, 366,
#             380, 382, 384, 408, 410, 413, 416, 417],
#            dtype='int64')

# %%
#Accessing rows

# %%
#Accessing the row having Age=NUll
df.iloc[age_null.index]
# Out:
#      PassengerId  Survived  Pclass  \
# 10           902         0       3
# 22           914         1       1
# 29           921         0       3
# 33           925         1       3
# 36           928         1       3
# ..           ...       ...     ...
# 408         1300         1       3
# 410         1302         1       3
# 413         1305         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 10                                    Ilieff, Mr. Ylio    male  NaN      0
# 22                Flegenheim, Mrs. Alfred (Antoinette)  female  NaN      0
# 29                                   Samaan, Mr. Elias    male  NaN      2
# 33   Johnston, Mrs. Andrew G (Elizabeth Lily" Watson)"  female  NaN      1
# 36                                 Roth, Miss. Sarah A  female  NaN      0
# ..                                                 ...     ...  ...    ...
# ...

# %%
df.iloc[[1,2,3,4,5,10]]
# Out:
#     PassengerId  Survived  Pclass  \
# 1           893         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# 5           897         0       3
# 10          902         0       3
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 1               Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                      Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                               Wirz, Mr. Albert    male  27.0      0      0
# 4   Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                     Svensson, Mr. Johan Cervin    male  14.0      0      0
# 10                              Ilieff, Mr. Ylio    male   NaN      0      0
#
#      Ticket     Fare Cabin Embarked           Ocean  Class
# 1    363272   7.0000   NaN        S  North Atlantic      3
# 2    240276   9.6875   NaN        Q  North Atlantic      2
# ...

# %%
df[df["Fare"]==max(df["Fare"])]
# Out:
#      PassengerId  Survived  Pclass  \
# 343         1235         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 343  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0      0
#
#      Parch    Ticket      Fare        Cabin Embarked           Ocean  Class
# 343      1  PC 17755  512.3292  B51 B53 B55        C  North Atlantic      1

# %%
#extracting the name of the passenger who paid maximunm fare.
df[df["Fare"]==max(df["Fare"])]["Name"]
# Out:
# 343    Cardeza, Mrs. James Warburton Martinez (Charlo...
# Name: Name, dtype: object

# %%
df["new_col"]=df["Age"]+df["Pclass"]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked           Ocean  Class  new_col
# 0   330911   7.8292   NaN        Q  North Atlantic      3     37.5
# 1   363272   7.0000   NaN        S  North Atlantic      3     50.0
# 2   240276   9.6875   NaN        Q  North Atlantic      2     64.0
# ...

# %%
df=pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv",sep="\t")

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
pd.Categorical(df["item_name"])
# Out:
# ['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar', 'Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl', ..., 'Steak Burrito', 'Steak Burrito', 'Chicken Salad Bowl', 'Chicken Salad Bowl', 'Chicken Salad Bowl']
# Length: 4622
# Categories (50, object): ['6 Pack Soft Drink', 'Barbacoa Bowl', 'Barbacoa Burrito', 'Barbacoa Crispy Tacos', ..., 'Veggie Crispy Tacos', 'Veggie Salad', 'Veggie Salad Bowl', 'Veggie Soft Tacos']

# %%
df["item_name"].unique()
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar',
#        'Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl',
#        'Side of Chips', 'Steak Burrito', 'Steak Soft Tacos',
#        'Chips and Guacamole', 'Chicken Crispy Tacos',
#        'Chicken Soft Tacos', 'Chicken Burrito', 'Canned Soda',
#        'Barbacoa Burrito', 'Carnitas Burrito', 'Carnitas Bowl',
#        'Bottled Water', 'Chips and Tomatillo Green Chili Salsa',
#        'Barbacoa Bowl', 'Chips', 'Chicken Salad Bowl', 'Steak Bowl',
#        'Barbacoa Soft Tacos', 'Veggie Burrito', 'Veggie Bowl',
#        'Steak Crispy Tacos', 'Chips and Tomatillo Red Chili Salsa',
#        'Barbacoa Crispy Tacos', 'Veggie Salad Bowl',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Roasted Chili Corn Salsa', 'Carnitas Soft Tacos',
#        'Chicken Salad', 'Canned Soft Drink', 'Steak Salad Bowl',
#        '6 Pack Soft Drink', 'Chips and Tomatillo-Red Chili Salsa', 'Bowl',
# ...

# %%
df.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
df.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
df1=df[df.dtypes[df.dtypes=="O"].index]

# %%
df1.tail()
# Out:
#                item_name                                 choice_description  \
# 4617       Steak Burrito  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...
# 4618       Steak Burrito  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...
# 4619  Chicken Salad Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# 4620  Chicken Salad Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...
# 4621  Chicken Salad Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
#
#      item_price
# 4617    $11.75
# 4618    $11.75
# 4619    $11.25
# 4620     $8.75
# 4621     $8.75

# %%
df1.describe()
# Out:
#            item_name choice_description item_price
# count           4622               3376       4622
# unique            50               1043         78
# top     Chicken Bowl        [Diet Coke]     $8.75
# freq             726                134        730

# %%
df.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
df["New_Col"]=df['item_price']

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price  New_Col
# 0                                                   NaN     $2.39    $2.39
# ...

# %%
df["item_price"]=df["item_price"].str.replace("$"," ") 
df.head()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_32820\3356813446.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["item_price"]=df["item_price"].str.replace("$"," ")
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price  New_Col
# 0                                                NaN      2.39    $2.39
# 1                                       [Clementine]      3.39    $3.39
# ...

# %%
df["choice_description"].unique()
# Out:
# array([nan, '[Clementine]', '[Apple]', ...,
#        '[Roasted Chili Corn Salsa, [Pinto Beans, Sour Cream, Cheese, Lettuce, Guacamole]]',
#        '[Tomatillo Green Chili Salsa, [Rice, Black Beans]]',
#        '[Tomatillo Green Chili Salsa, [Rice, Fajita Vegetables, Black Beans, Guacamole]]'],
#       dtype=object)

# %%
df["quantity"].max()
# Out:
# 15

# %%
df1.iloc[1:10:2]
# Out:
#                                item_name  \
# 1                                   Izze
# 3  Chips and Tomatillo-Green Chili Salsa
# 5                           Chicken Bowl
# 7                          Steak Burrito
# 9                          Steak Burrito
#
#                                   choice_description item_price
# 1                                       [Clementine]     $3.39
# 3                                                NaN     $2.39
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 9  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25

# %%
df1=df.loc[df["item_name"]=="Steak Burrito"]
df1
# Out:
#       order_id  quantity      item_name  \
# 7            4         1  Steak Burrito
# 9            5         1  Steak Burrito
# 31          16         1  Steak Burrito
# 43          20         1  Steak Burrito
# 46          21         1  Steak Burrito
# ...        ...       ...            ...
# 4546      1807         1  Steak Burrito
# 4607      1829         1  Steak Burrito
# 4610      1830         1  Steak Burrito
# 4617      1833         1  Steak Burrito
# 4618      1833         1  Steak Burrito
#
#                                      choice_description item_price  New_Col
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...     11.75   $11.75
# 9     [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...      9.25    $9.25
# 31    [[Roasted Chili Corn Salsa (Medium), Fresh Tom...      8.99    $8.99
# 43    [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...     11.75   $11.75
# 46    [Tomatillo-Red Chili Salsa (Hot), [Rice, Fajit...      8.99    $8.99
# ...

# %%
df1.shape
# Out:
# (368, 6)

# %%
#Accessing rows
df1.loc[[7]]
# Out:
#    order_id  quantity      item_name  \
# 7         4         1  Steak Burrito
#
#                                   choice_description item_price  New_Col
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...     11.75   $11.75

# %%
df1.iloc[[1,2,3]]
# Out:
#     order_id  quantity      item_name  \
# 9          5         1  Steak Burrito
# 31        16         1  Steak Burrito
# 43        20         1  Steak Burrito
#
#                                    choice_description item_price  New_Col
# 9   [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...      9.25    $9.25
# 31  [[Roasted Chili Corn Salsa (Medium), Fresh Tom...      8.99    $8.99
# 43  [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...     11.75   $11.75

# %%
#merging the two dataset 
series1={
    "Name":["x","y","z"],
    "USN":[1,2,3]
}
series2={
    "USN":[1,2,3],
    "Batch":["DS","AI","IOT"],
    "Age":[19,20,21]
}

# %%
df1=pd.DataFrame(series1)
df2=pd.DataFrame(series2)

# %%
df1.head()
# Out:
#   Name  USN
# 0    x    1
# 1    y    2
# 2    z    3

# %%
df2.head()
# Out:
#    USN Batch  Age
# 0    1    DS   19
# 1    2    AI   20
# 2    3   IOT   21

# %%
pd.merge(df1,df2,on="USN")
# Out:
#   Name  USN Batch  Age
# 0    x    1    DS   19
# 1    y    2    AI   20
# 2    z    3   IOT   21

# %%
pd.merge(df1,df2,how="inner",on="USN")
# Out:
#   Name  USN Batch  Age
# 0    x    1    DS   19
# 1    y    2    AI   20
# 2    z    3   IOT   21

# %%
#merging the two dataset 
series1={
    "Name":["x","y","z"],
    "USN":[1,2,3]
}
series2={
    "USN":[1,2],
    "Batch":["DS","AI"],
    "Age":[19,20]
}

# %%
df1=pd.DataFrame(series1)
df2=pd.DataFrame(series2)

# %%
pd.merge(df1,df2,how="inner",on="USN")
# Out:
#   Name  USN Batch  Age
# 0    x    1    DS   19
# 1    y    2    AI   20

# %%
pd.merge(df1,df2,how="left",on="USN")  #all the rows in left and common.
# Out:
#   Name  USN Batch   Age
# 0    x    1    DS  19.0
# 1    y    2    AI  20.0
# 2    z    3   NaN   NaN

# %%
#merging the two dataset 
series1={
    "Name":["x","y"],
    "USN":[1,2]
}
series2={
    "USN":[1,2,3],
    "Batch":["DS","AI","IOT"],
    "Age":[19,20,18]
}

# %%
df1=pd.DataFrame(series1)
df2=pd.DataFrame(series2)

# %%
pd.merge(df1,df2,how="right",on="USN")  #all the rows in right and common.
# Out:
#   Name  USN Batch  Age
# 0    x    1    DS   19
# 1    y    2    AI   20
# 2  NaN    3   IOT   18

# %%
pd.merge(df1,df2,how="outer",on="USN")
# Out:
#   Name  USN Batch  Age
# 0    x    1    DS   19
# 1    y    2    AI   20
# 2  NaN    3   IOT   18

# %%
#joining two dataframe.

# %%
df1=pd.read_csv("billionaire.csv")
df1.head()
# Out:
#    Unnamed: 0                          name   last_name  age gender  time  \
# 0         675  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M  2013
# 1         676  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M  2013
# 2         677  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M  2013
# 3         678  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M  2013
# 4         679  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M  2013
#
#             permanent_country       company main_industry  \
# 0  United Arab Emirates-Dubai  Mashreq Bank   Diversified
# 1  United Arab Emirates-Dubai  Mashreq Bank   Diversified
# 2  United Arab Emirates-Dubai  Mashreq Bank   Diversified
# 3  United Arab Emirates-Dubai  Mashreq Bank   Diversified
# 4  United Arab Emirates-Dubai  Mashreq Bank   Diversified
#
#   wealth_source_details             industry state headquarters countries  \
# 0           diversified  Diversified;Banking   NaN          NaN       are
# ...

# %%
df1.shape
# Out:
# (352369, 18)

# %%
df2=pd.read_csv("Titanic.csv")

df2.shape
# Out:
# (418, 12)

# %%
df=df1.join(df2)

# %%
df.head()
# Out:
#    Unnamed: 0                          name   last_name  age gender  time  \
# 0         675  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M  2013
# 1         676  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M  2013
# 2         677  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M  2013
# 3         678  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M  2013
# 4         679  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M  2013
#
#             permanent_country       company main_industry  \
# 0  United Arab Emirates-Dubai  Mashreq Bank   Diversified
# 1  United Arab Emirates-Dubai  Mashreq Bank   Diversified
# 2  United Arab Emirates-Dubai  Mashreq Bank   Diversified
# 3  United Arab Emirates-Dubai  Mashreq Bank   Diversified
# 4  United Arab Emirates-Dubai  Mashreq Bank   Diversified
#
#   wealth_source_details  ... Pclass  \
# 0           diversified  ...    3.0
# 1           diversified  ...    3.0
# 2           diversified  ...    2.0
# ...

# %%
df.shape
# Out:
# (352369, 30)
