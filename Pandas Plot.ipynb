# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
np.random.seed(20)
df=pd.DataFrame(np.random.rand(1000,1),index=[pd.date_range("2023-11-03",periods=1000)],columns=["data"])

# %%
df
# Out:
#                 data
# 2023-11-03  0.588131
# 2023-11-04  0.897714
# 2023-11-05  0.891531
# 2023-11-06  0.815837
# 2023-11-07  0.035890
# ...              ...
# 2026-07-25  0.992189
# 2026-07-26  0.756037
# 2026-07-27  0.299186
# 2026-07-28  0.261712
# 2026-07-29  0.968979
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize=(20,5))
# Out:
# <AxesSubplot:>

# %%
df.data.cumsum().plot(figsize=(15,3))
# Out:
# <AxesSubplot:>

# %%
df["data1"]=df.data.cumsum()
df["data2"]=df["data"].apply(lambda i:np.log(i))

# %%
df.plot(figsize=(20,5))
# Out:
# <AxesSubplot:>

# %%
df=sns.load_dataset("iris")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df1=df.plot(figsize=(10,6),title="Flowers")
df1.set_xlabel("X_axis")
df1.set_ylabel("Y_axis")
# Out:
# Text(0, 0.5, 'Y_axis')

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.iloc[0][0:4].plot()
# Out:
# <AxesSubplot:>

# %%
df.iloc[0][0:4].plot(kind="bar")  #extracting a first row of datase and plotting in bar graph.
# Out:
# <AxesSubplot:>

# %%
df=pd.DataFrame(np.random.rand(10,5),columns=["a","b","c","d","e"])
df
# Out:
#           a         b         c         d         e
# 0  0.171016  0.381166  0.350981  0.676423  0.042550
# 1  0.979180  0.145353  0.483505  0.774244  0.723839
# 2  0.731808  0.300705  0.242525  0.632726  0.512675
# 3  0.751299  0.197718  0.880508  0.623336  0.723082
# 4  0.347911  0.182564  0.598275  0.743349  0.745970
# 5  0.375282  0.126487  0.697399  0.247933  0.859607
# 6  0.324106  0.159783  0.030880  0.944616  0.218304
# 7  0.501676  0.180281  0.613731  0.657580  0.858250
# 8  0.407631  0.148860  0.363654  0.508080  0.776058
# 9  0.169837  0.449848  0.612549  0.753895  0.410971

# %%
df.plot()  #it will plot a line graph based on index.
# Out:
# <AxesSubplot:>

# %%
df1=df.plot(figsize=(10,5),kind="bar")
df1.set_xlabel("Index")
df1.set_ylabel("values")
# Out:
# Text(0, 0.5, 'values')

# %%
df.plot.barh(figsize=(5,8))  #rotation of the graph above.
# Out:
# <AxesSubplot:>

# %%
df.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df2=sns.load_dataset("iris")
df2.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df2.plot.hist()   #x axis represent range and y axis represent frequency.
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df2.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df2["sepal_width"].hist(color="#008080")
# Out:
# <AxesSubplot:>

# %%
df2.plot(kind="hist",stacked=True,bins=60)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df2.plot(kind="hist",stacked=False,bins=60)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df2.hist()
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df2.hist(figsize=(10,10), color= "#cc80ff" ,alpha=0.9) #we can select any colour by html colour picker and copy the colour code.
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df2.hist(figsize=(10,10), color= "#008080" ,alpha=0.1)  #alpha determine the transparency of the graph.
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df2.plot.scatter(x="sepal_width",y="petal_width")
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>

# %%
df2.plot.scatter(x="sepal_length",y="petal_length")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df2.plot.scatter(x="sepal_length",y="petal_width")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %%
df2.plot.scatter(x="sepal_length",y="petal_width",c="petal_width")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %%
df2.plot.scatter(x="sepal_width",y="sepal_length",label="Neetesh", s=200 , c="petal_length")
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>

# %%
df2.plot.hexbin(x="sepal_width",y="sepal_length",gridsize=10)
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>

# %%
df3=df.iloc[0]
df3
# Out:
# a    0.171016
# b    0.381166
# c    0.350981
# d    0.676423
# e    0.042550
# Name: 0, dtype: float64

# %%
df3.plot.pie(figsize=(6,6))
# Out:
# <AxesSubplot:ylabel='0'>

# %%
df4=df2.head(3).T

# %%
df4.iloc[:4].plot.pie(subplots=True,figsize=(20,20))
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
df4.iloc[:4].plot.pie(subplots=True,figsize=(20,20),fontsize=13,autopct="%.2f")
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
pd.plotting.scatter_matrix(df2,figsize=(12,10))
# Out:
# array([[<AxesSubplot:xlabel='sepal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>,
# ...

# %%
pd.plotting.scatter_matrix(df2,figsize=(12,10),diagonal="kde")
# Out:
# array([[<AxesSubplot:xlabel='sepal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>,
# ...

# %%
df2["sepal_length"].plot(color="#006600", legend=True, label="Sep_Len")
# Out:
# <AxesSubplot:>

# %%
df2["sepal_length"].plot(style="r*", legend=True, label="Sep_Len")
# Out:
# <AxesSubplot:>

# %%
df2["sepal_length"].plot(figsize=(14,6),style="g--", legend=True, label="Sep_Len")
# Out:
# <AxesSubplot:>

# %%
df2["sepal_length"].plot(figsize=(14,6),style="b-*", legend=True, label="Sep_Len")
# Out:
# <AxesSubplot:>

# %%
df2["sepal_length"].plot(figsize=(14,6),style="--*",color="#66ff1a",legend=True, label="Sep_Len")
# Out:
# <AxesSubplot:>

# %%
import plotly.offline as iplot
import plotly as py
import plotly.tools as tls
import cufflinks as cf

# %%
py.__version__
# Out:
# '5.6.0'

# %%
py.offline.init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
# ...

# %%
df2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df2.plot()
# Out:
# <AxesSubplot:>

# %%
df2.iplot()  #we can go to export to plo.ly and do any changes in data and see what ll be the chnage in it.
# Out:
# <div>                            <div id="e0ff519e-eff7-4443-9807-ebe48f3fae73" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
#There are many tools like tibco spotfire,bokeh, plotly, cufflinks , matplotlib, matlab, tableau, powerbi for visualization purpose.

# %%
df=sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.iplot(kind="scatter",x="age",y="fare",mode="markers",colors= "red", title='Age vs Fare',xTitle='Age',yTitle='Fare')
# Out:
# <div>                            <div id="504c7bee-a627-4619-8e55-b1dba2bbf787" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
cf.getTheme()
# Out:
# {'colorscale': 'original',
#  'linewidth': 1.3,
#  'bargap': 0.01,
#  'layout': {'legend': {'bgcolor': '#F5F6F9', 'font': {'color': '#4D5663'}},
#   'paper_bgcolor': '#F5F6F9',
#   'plot_bgcolor': '#F5F6F9',
#   'yaxis': {'tickfont': {'color': '#4D5663'},
#    'gridcolor': '#E1E5ED',
#    'titlefont': {'color': '#4D5663'},
#    'zerolinecolor': '#E1E5ED',
#    'showgrid': True},
#   'xaxis': {'tickfont': {'color': '#4D5663'},
#    'gridcolor': '#E1E5ED',
#    'titlefont': {'color': '#4D5663'},
#    'zerolinecolor': '#E1E5ED',
#    'showgrid': True},
#   'titlefont': {'color': '#4D5663'}},
#  'annotations': {'fontcolor': '#4D5663', 'arrowcolor': '#9499A3'},
#  '3d': {'yaxis': {'gridcolor': '#9499A3', 'zerolinecolor': '#9499A3'},
#   'xaxis': {'gridcolor': '#9499A3', 'zerolinecolor': '#9499A3'}}}

# %%
cf.set_config_file(theme="solar")
df.iplot(kind="scatter",x="age",y="fare",mode="markers",colors= "pink", title='Age vs Fare',xTitle='Age',yTitle='Fare')
# Out:
# <div>                            <div id="79ce139c-5e34-4f74-99f2-547609dd9520" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
